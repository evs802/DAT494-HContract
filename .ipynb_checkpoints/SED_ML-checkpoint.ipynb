# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np  
import seaborn as sns  
import tensorflow as tf  
from tensorflow import keras 
from keras import layers
from sklearn.ensemble import RandomForestRegressor  
from sklearn.preprocessing import StandardScaler  
from sklearn.metrics import mean_squared_error, r2_score  
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, KFold
# Out:
# 2025-02-01 16:46:00.816907: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-01 16:46:00.817835: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-01 16:46:00.820351: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-01 16:46:00.827822: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738453560.841440   23679 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738453560.845293   23679 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-01 16:46:00.859571: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Load in CAT files
df_mag = pd.read_csv('NEP14_CohenMAGS.cat',header=5,sep=r'\s+')
df_sed = pd.read_csv('NEP14_CohenSED.cat',header=3,sep=r'\s+')

#Clean Columns
#MAG
mag_col_names = list(df_mag.columns.drop(['#','(deg)']))
mag_col_names[1] = 'RA(deg)'
df_mag_clean = df_mag.iloc[:,:-2].set_axis(mag_col_names,axis=1).dropna()
df_mag_clean['ID'] = df_mag_clean['ID'].astype(float)
display(df_mag_clean)

#SED
sed_col_names = [s.replace(',', '') for s in list(df_sed.columns.drop(['#','sq.,']))]
sed_col_names[6] = 'chi sq.'
df_sed_clean = df_sed.iloc[1:,:-2].set_axis(sed_col_names,axis=1).reset_index(drop=True).dropna()
df_sed_clean['ID'] = df_sed_clean['ID'].astype(float)
display(df_sed_clean)
# Merge on "ID"
df_merged = df_mag_clean.merge(df_sed_clean, on="ID",how='right').astype(float)
df_merged = df_merged.loc[df_merged['F444W'] <=30]
df_merged = df_merged.loc[~np.isinf(df_merged['Log10(SSFR)'].astype(float))]
display((df_merged))
# Out:
#             ID     RA(deg)   Dec(deg)    F090W    F115W    F150W    F200W  \
# 0          1.0  260.718976  65.711171  18.7847  18.6773  18.8318  18.9775
# 1          2.0  260.731025  65.710601  18.3673  18.1124  17.9475  17.8704
# 2          3.0  260.671726  65.711675  17.7597  17.2200  16.8639  16.6053
# 3          4.0  260.724918  65.709605  21.6962  21.4863  21.3460  21.4604
# 4          5.0  260.751843  65.708582  25.5848  25.5662  25.5087  25.3979
# ...        ...         ...        ...      ...      ...      ...      ...
# 37863  39117.0  260.672816  65.904928  22.0350  21.9733  21.8381  21.7456
# 37864  36603.0  260.666303  65.901720  28.0913  27.6933  27.2214  26.6518
# 37865  41620.0  260.661086  65.906960  27.4219  27.4504  27.5667  27.2882
# 37866  38911.0  260.702667  65.875949  27.4436  26.9181  26.2983  26.2320
# 37867  36212.0  260.703578  65.874818  29.9849  29.1880  28.0053  27.8448
#
#          F277W    F356W    F410M    F444W  eF090W  eF115W  eF150W  eF200W  \
# 0      19.6117  19.8170  20.2598  20.3863  0.0700  0.0701  0.0700  0.0700
# 1      18.0502  18.3024  18.4486  18.5508  0.0700  0.0700  0.0700  0.0702
# 2      16.6891  17.0728  17.0368  17.2670  0.0700  0.0700  0.0700  0.0700
# 3      23.0741  23.1244  23.2145  23.3691  0.0701  0.0731  0.0727  0.0701
# 4      24.7714  24.7934  25.1194  24.9991  0.0815  0.0809  0.0787  0.0757
# ...        ...      ...      ...      ...     ...     ...     ...     ...
# 37863  21.8421  22.3119  22.4508  22.4028  0.0701  0.0700  0.0700  0.0700
# ...        ...         ...        ...      ...      ...      ...      ...
# 37719  39117.0  260.672816  65.904928  22.0350  21.9733  21.8381  21.7456
# 37720  36603.0  260.666303  65.901720  28.0913  27.6933  27.2214  26.6518
# 37721  41620.0  260.661086  65.906960  27.4219  27.4504  27.5667  27.2882
# 37722  38911.0  260.702667  65.875949  27.4436  26.9181  26.2983  26.2320
# 37723  36212.0  260.703578  65.874818  29.9849  29.1880  28.0053  27.8448
#
#          F277W    F356W    F410M  ...  DEC(J2000)  z_m1(EAZY)  log10(mass)  \
# 0      19.6117  19.8170  20.2598  ...   65.711171       0.075     8.024576
# 1      18.0502  18.3024  18.4486  ...   65.710601       0.446    10.559864
# 2      16.6891  17.0728  17.0368  ...   65.711675       0.259    10.944576
# 3      23.0741  23.1244  23.2145  ...   65.709605       0.018     5.689755
# 4      24.7714  24.7934  25.1194  ...   65.708582       4.715     9.813772
# ...        ...      ...      ...  ...         ...         ...          ...
# 37719  21.8421  22.3119  22.4508  ...   65.904928       0.454     8.765012
# 37720  26.6035  26.7834  26.6136  ...   65.901720       0.499     7.283634
# 37721  26.8604  26.9123  26.9335  ...   65.906960       4.786     8.939743
# 37722  26.1292  26.3350  26.4955  ...   65.875949       0.423     7.312332
# 37723  27.8015  28.0400  28.3416  ...   65.874818       0.392     7.591309
#
#        log10(age)     chi sq.  Log10(SSFR)  Log10(Tau)  A_V  nfilt  F444W_AB
# 0       -2.040001    7.724554     1.827012   -2.000000  0.0    8.0   20.3863
# 1       -2.220000    0.866112     2.184449   -1.428291  2.4    8.0   18.5508
# 2       -0.843454    3.219007    -4.227740   -2.000000  1.8    8.0   17.2670
# 3       -2.080001  141.343780     1.886938   -2.000000  0.0    8.0   23.3691
# 4       -0.693453   17.567767    -0.052254   -1.142668  0.0    8.0   24.9991
# ...           ...         ...          ...         ...  ...    ...       ...
# 37719   -1.043455    4.177360     1.043258    2.000000  0.2    8.0   22.4028
# 37720   -2.200001    6.419984     2.127079   -1.714443  4.0    8.0   26.7546
# 37721   -0.893456    2.477451    -0.045416   -1.428291  0.0    8.0   27.0008
# 37722   -2.220000    5.361995     2.150443   -1.714443  3.6    8.0   26.4607
# 37723    0.676694    7.187283  -204.289889   -2.000000  1.4    8.0   28.2298
#
# [35264 rows x 30 columns]

# %%
# Define input features and target variables
input_features = ["F090W", "F150W", "F200W", "F277W", "F356W", "F410M", "F444W", "z_m1(EAZY)"]
target_variables = ["log10(mass)", "log10(age)", "Log10(SSFR)", "Log10(Tau)", "A_V", "chi sq."]

# Split data into train and test sets
X = df_merged[input_features]
y = df_merged[target_variables]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize input features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# Train the Random Forest model
regr = RandomForestRegressor()
regr.fit(X_train_scaled, y_train_scaled)

# Make predictions
predictions_scaled = regr.predict(X_test_scaled)

# Inverse transform the predictions back to original scale
predictions = scaler_y.inverse_transform(predictions_scaled)
y_test_original = scaler_y.inverse_transform(y_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test_original, predictions)
r2 = r2_score(y_test_original, predictions)

# Output the results
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 97.670840665825
# R-squared: 0.5827571386967981

# %% [markdown]
# GridSearchCV

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 300, 500],  # Number of trees
    'max_depth': [10, 20, None],  # Depth of trees
    'min_samples_split': [2, 5, 10],  # Minimum samples to split
    'min_samples_leaf': [1, 2, 4],  # Minimum samples per leaf
    'max_features': ['auto', 'sqrt'],  # Number of features per split
}

# Initialize RandomForestRegressor
rf = RandomForestRegressor(random_state=42)

# Perform GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, scoring='r2', verbose=2, n_jobs=-1)

# Fit GridSearchCV to training data
grid_search.fit(X_train_scaled, y_train_scaled)

# Get the best model
best_rf = grid_search.best_estimator_

# Evaluate on test set
predictions_scaled = best_rf.predict(X_test_scaled)

# Inverse transform predictions
predictions = scaler_y.inverse_transform(predictions_scaled)
y_test_original = scaler_y.inverse_transform(y_test_scaled)

# Compute metrics
mse = mean_squared_error(y_test_original, predictions)
r2 = r2_score(y_test_original, predictions)

print(f'Best Parameters: {grid_search.best_params_}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  31.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  28.4s
# /home/evan/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  28.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  28.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  19.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  20.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  20.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  33.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  17.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  20.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  30.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  36.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  32.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  27.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  27.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  28.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  17.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  17.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  17.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  18.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  31.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  34.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  31.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  32.6s

# %%
# Get feature importances
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Plot feature importances
plt.figure(figsize=(8, 6))
plt.bar(range(len(input_features)), importances[indices], align="center")
plt.xticks(range(len(input_features)), np.array(input_features)[indices], rotation=45, ha="right")
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance (Random Forest)")
plt.show()

# %% [markdown]
# SVM (SVR) for Log10(mass)

# %%
df_filtered = df_merged.loc[df_merged['F444W'] <= 25]

#Define input features and target variables
input_features = ["F090W", "F150W", "F200W", "F277W", "F356W", "F410M", "F444W", "z_m1(EAZY)"]
target_variables = ["log10(mass)", "log10(age)", "Log10(SSFR)", "Log10(Tau)", "A_V", "chi sq."]

# Step 3: Prepare input/output datasets
X = df_filtered[input_features]
y = df_filtered[target_variables]

# Step 4: Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize input and output variables
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# Step 6: Train an SVM model (RBF Kernel)
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)  # Adjust C and gamma if needed
svr.fit(X_train_scaled, y_train_scaled[:, 0])  # Training on first target variable for now (log10(mass))

# Step 7: Make predictions
predictions_scaled = svr.predict(X_test_scaled)

# Reshape predictions
predictions_scaled = predictions_scaled.reshape(-1, 1)

# Step 8: Inverse transform predictions to original scale
predictions = scaler_y.inverse_transform(np.hstack([predictions_scaled, np.zeros((predictions_scaled.shape[0], y_train.shape[1] - 1))]))[:, 0]

# Step 9: Evaluate the model
mse_svm = mean_squared_error(y_test["log10(mass)"], predictions)
r2_svm = r2_score(y_test["log10(mass)"], predictions)

# Print results
print(f'SVM Mean Squared Error: {mse_svm}')
print(f'SVM R-squared: {r2_svm}')
# Out:
# SVM Mean Squared Error: 0.09216751028311217
# SVM R-squared: 0.9117801833176159

# %% [markdown]
# Now we train seperate models for all target variables, SVM only used to predict one output at a time

# %%
df_filtered = df_merged.loc[df_merged['F444W'] <= 25]

# Define input features and target variables
input_features = ["F090W", "F150W", "F200W", "F277W", "F356W", "F410M", "F444W", "z_m1(EAZY)"]
target_variables = ["log10(mass)", "log10(age)", "Log10(SSFR)", "Log10(Tau)", "A_V", "chi sq."]

# Prepare input/output datasets
X = df_filtered[input_features]
y = df_filtered[target_variables]

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize input and output variables
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# Train an SVM model for each target variable
svr_models = {}
predictions_scaled = []

for i, target in enumerate(target_variables):
    svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)  # Default parameters for now
    svr.fit(X_train_scaled, y_train_scaled[:, i])
    svr_models[target] = svr

    # Predict and store scaled predictions
    pred_scaled = svr.predict(X_test_scaled)
    predictions_scaled.append(pred_scaled)

# Convert predictions list to array and reshape
predictions_scaled = np.array(predictions_scaled).T  # Shape: (samples, targets)

# Inverse transform predictions to original scale
predictions = scaler_y.inverse_transform(predictions_scaled)

#Evaluate the model for each target variable
mse_results = {}
r2_results = {}

for i, target in enumerate(target_variables):
    mse_results[target] = mean_squared_error(y_test[target], predictions[:, i])
    r2_results[target] = r2_score(y_test[target], predictions[:, i])

# Print results
print("SVM Performance for Each Target Variable:")
for target in target_variables:
    print(f"{target} - MSE: {mse_results[target]:.5f}, R²: {r2_results[target]:.5f}")
# Out:
# SVM Performance for Each Target Variable:
# log10(mass) - MSE: 0.09217, R²: 0.91178
# log10(age) - MSE: 0.70417, R²: 0.31520
# Log10(SSFR) - MSE: 194.60233, R²: 0.02085
# Log10(Tau) - MSE: 2.06857, R²: 0.00065
# A_V - MSE: 0.63387, R²: 0.63760
# chi sq. - MSE: 538.03893, R²: 0.77303

# %%
# Define the parameter grid for fine-tuning
param_grid = {
    'C': [1, 10, 50, 100, 200, 500, 1000],  # Wide range of C values
    'gamma': ['scale', 0.001, 0.01, 0.1, 0.5, 1],  # Various levels of complexity
    'epsilon': [0.001, 0.01, 0.1, 0.5, 1, 2]  # Different tolerance levels
}

# Initialize SVR model
svr = SVR(kernel='rbf')

# Run GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(svr, param_grid, cv=5, scoring='r2', verbose=2, n_jobs=-1)

# Fit GridSearchCV to training data
grid_search.fit(X_train_scaled, y_train_scaled[:, 0])  # Only optimizing for log10(mass)

# Get the best parameters
best_params = grid_search.best_params_
best_svr = grid_search.best_estimator_

# Make predictions with the best model
predictions_scaled = best_svr.predict(X_test_scaled).reshape(-1, 1)

# Inverse transform predictions to original scale
predictions = scaler_y.inverse_transform(np.hstack([predictions_scaled, np.zeros((predictions_scaled.shape[0], y_train.shape[1] - 1))]))[:, 0]

# Evaluate the best model
mse_best = mean_squared_error(y_test["log10(mass)"], predictions)
r2_best = r2_score(y_test["log10(mass)"], predictions)

# Print best parameters and performance
print(f'Best Parameters: {best_params}')
print(f'Optimized SVM Mean Squared Error: {mse_best}')
print(f'Optimized SVM R-squared: {r2_best}')
# Out:
# Fitting 5 folds for each of 252 candidates, totalling 1260 fits
# [CV] END ....................C=1, epsilon=0.001, gamma=0.001; total time=   0.5s
# [CV] END .....................C=1, epsilon=0.001, gamma=0.01; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.001, gamma=0.5; total time=   0.5s
# [CV] END ........................C=1, epsilon=0.001, gamma=1; total time=   0.6s
# [CV] END .....................C=1, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END .......................C=1, epsilon=0.01, gamma=0.1; total time=   0.5s
# [CV] END .......................C=1, epsilon=0.01, gamma=0.5; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.1, gamma=scale; total time=   0.4s
# [CV] END ......................C=1, epsilon=0.1, gamma=0.001; total time=   0.4s
# [CV] END .......................C=1, epsilon=0.1, gamma=0.01; total time=   0.4s
# [CV] END ........................C=1, epsilon=0.1, gamma=0.5; total time=   0.4s
# [CV] END ......................C=1, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END ......................C=1, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END ......................C=1, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .......................C=1, epsilon=0.5, gamma=0.01; total time=   0.2s
# [CV] END ........................C=1, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END ........................C=1, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END ........................C=1, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END .........................C=1, epsilon=1, gamma=0.01; total time=   0.0s
# [CV] END ............................C=1, epsilon=1, gamma=1; total time=   0.0s
# [CV] END ............................C=1, epsilon=1, gamma=1; total time=   0.0s
# [CV] END ...................C=10, epsilon=0.001, gamma=scale; total time=   0.6s
# [CV] END ...................C=10, epsilon=0.001, gamma=scale; total time=   0.6s
# [CV] END ...................C=10, epsilon=0.001, gamma=scale; total time=   0.6s
# [CV] END ...................C=10, epsilon=0.001, gamma=scale; total time=   0.7s
# [CV] END ......................C=10, epsilon=0.01, gamma=0.1; total time=   0.6s
# [CV] END ......................C=10, epsilon=0.01, gamma=0.1; total time=   0.7s
# [CV] END ......................C=10, epsilon=0.01, gamma=0.5; total time=   0.9s
# [CV] END ......................C=10, epsilon=0.01, gamma=0.5; total time=   0.9s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.1; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.1; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END ........................C=10, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END ........................C=10, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END ........................C=10, epsilon=1, gamma=0.01; total time=   0.0s
# [CV] END .........................C=10, epsilon=1, gamma=0.1; total time=   0.1s
# [CV] END .........................C=10, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END ........................C=10, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ........................C=10, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ........................C=10, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ........................C=10, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ...........................C=10, epsilon=2, gamma=1; total time=   0.0s
# [CV] END ...........................C=10, epsilon=2, gamma=1; total time=   0.0s
# [CV] END ...........................C=10, epsilon=2, gamma=1; total time=   0.0s
# [CV] END ...........................C=10, epsilon=2, gamma=1; total time=   0.0s
# [CV] END ...........................C=10, epsilon=2, gamma=1; total time=   0.0s
# [CV] END ...................C=50, epsilon=0.001, gamma=scale; total time=   1.2s
# [CV] END ...................C=50, epsilon=0.001, gamma=0.001; total time=   0.5s
# [CV] END ....................C=50, epsilon=0.001, gamma=0.01; total time=   0.6s
# [CV] END .....................C=50, epsilon=0.001, gamma=0.1; total time=   1.1s
# [CV] END .....................C=50, epsilon=0.001, gamma=0.5; total time=   2.7s
# [CV] END ....................C=50, epsilon=0.01, gamma=scale; total time=   1.1s
# [CV] END ....................C=50, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END ....................C=50, epsilon=0.01, gamma=0.001; total time=   0.6s
# [CV] END ....................C=50, epsilon=0.01, gamma=0.001; total time=   0.6s
# [CV] END .....................C=50, epsilon=0.01, gamma=0.01; total time=   0.7s
# [CV] END ......................C=50, epsilon=0.01, gamma=0.5; total time=   2.4s
# [CV] END ........................C=50, epsilon=0.01, gamma=1; total time=   3.8s
# [CV] END .......................C=50, epsilon=0.1, gamma=0.5; total time=   1.6s
# [CV] END .....................C=50, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END .....................C=50, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END .....................C=50, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .....................C=50, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END ......................C=50, epsilon=0.5, gamma=0.01; total time=   0.1s
# [CV] END ......................C=50, epsilon=0.5, gamma=0.01; total time=   0.1s
# [CV] END .......................C=50, epsilon=0.5, gamma=0.1; total time=   0.1s
# [CV] END .......................C=50, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .........................C=50, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .......................C=50, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END .......................C=50, epsilon=1, gamma=0.001; total time=   0.0s
# [CV] END ........................C=50, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END .........................C=50, epsilon=1, gamma=0.1; total time=   0.1s
# [CV] END .........................C=50, epsilon=1, gamma=0.5; total time=   0.0s
# [CV] END ...........................C=50, epsilon=1, gamma=1; total time=   0.0s
# [CV] END ........................C=50, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ........................C=50, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END .........................C=50, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .........................C=50, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ..................C=100, epsilon=0.001, gamma=scale; total time=   1.6s
# [CV] END ..................C=100, epsilon=0.001, gamma=scale; total time=   1.7s
# [CV] END ...................C=100, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END ...................C=100, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END ...................C=100, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END ...................C=100, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END .....................C=100, epsilon=0.01, gamma=0.1; total time=   1.4s
# [CV] END .....................C=100, epsilon=0.01, gamma=0.1; total time=   1.4s
# [CV] END ....................C=1, epsilon=0.001, gamma=scale; total time=   0.5s
# [CV] END .....................C=1, epsilon=0.001, gamma=0.01; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.001, gamma=0.1; total time=   0.5s
# [CV] END ........................C=1, epsilon=0.001, gamma=1; total time=   0.6s
# [CV] END .....................C=1, epsilon=0.01, gamma=0.001; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.01, gamma=0.01; total time=   0.5s
# [CV] END .......................C=1, epsilon=0.01, gamma=0.1; total time=   0.5s
# [CV] END .........................C=1, epsilon=0.01, gamma=1; total time=   0.6s
# [CV] END .......................C=1, epsilon=0.1, gamma=0.01; total time=   0.4s
# [CV] END ........................C=1, epsilon=0.1, gamma=0.1; total time=   0.4s
# [CV] END ..........................C=1, epsilon=0.1, gamma=1; total time=   0.4s
# [CV] END ......................C=1, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .......................C=1, epsilon=0.5, gamma=0.01; total time=   0.2s
# [CV] END ........................C=1, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END ..........................C=1, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .........................C=1, epsilon=1, gamma=0.01; total time=   0.0s
# [CV] END ..........................C=1, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END ..........................C=1, epsilon=1, gamma=0.1; total time=   0.0s
# [CV] END .........................C=1, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END .........................C=1, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ..........................C=1, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ..........................C=1, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ..........................C=1, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ............................C=1, epsilon=2, gamma=1; total time=   0.0s
# [CV] END .....................C=10, epsilon=0.001, gamma=0.5; total time=   0.9s
# [CV] END .......................C=10, epsilon=0.001, gamma=1; total time=   1.3s
# [CV] END .......................C=10, epsilon=0.001, gamma=1; total time=   1.4s
# [CV] END .......................C=10, epsilon=0.001, gamma=1; total time=   1.3s
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=   0.1s
# [CV] END .....................C=10, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .....................C=10, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .....................C=10, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .....................C=10, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .....................C=10, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END ...........................C=10, epsilon=1, gamma=1; total time=   0.0s
# [CV] END ...........................C=10, epsilon=1, gamma=1; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .......................C=10, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END ........................C=10, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .........................C=10, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END ...................C=50, epsilon=0.001, gamma=scale; total time=   1.1s
# [CV] END ...................C=50, epsilon=0.001, gamma=0.001; total time=   0.5s
# [CV] END ...................C=50, epsilon=0.001, gamma=0.001; total time=   0.5s
# [CV] END ....................C=50, epsilon=0.001, gamma=0.01; total time=   0.6s
# [CV] END .....................C=50, epsilon=0.001, gamma=0.5; total time=   2.3s
# [CV] END .......................C=50, epsilon=0.001, gamma=1; total time=   5.3s
# [CV] END ......................C=50, epsilon=0.01, gamma=0.5; total time=   2.4s
# [CV] END .....................C=50, epsilon=0.1, gamma=scale; total time=   0.8s
# [CV] END .....................C=50, epsilon=0.1, gamma=scale; total time=   0.8s
# [CV] END .....................C=50, epsilon=0.1, gamma=0.001; total time=   0.4s
# [CV] END ......................C=50, epsilon=0.1, gamma=0.01; total time=   0.5s
# [CV] END .......................C=50, epsilon=0.1, gamma=0.1; total time=   0.8s
# [CV] END .........................C=50, epsilon=0.1, gamma=1; total time=   2.6s
# [CV] END .......................C=50, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .......................C=50, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END ........................C=50, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END .........................C=50, epsilon=1, gamma=0.1; total time=   0.1s
# [CV] END ...........................C=50, epsilon=1, gamma=1; total time=   0.0s
# [CV] END .......................C=50, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .......................C=50, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .........................C=50, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .........................C=50, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END ..................C=100, epsilon=0.001, gamma=scale; total time=   1.7s
# [CV] END ..................C=100, epsilon=0.001, gamma=scale; total time=   1.6s
# [CV] END ...................C=100, epsilon=0.01, gamma=scale; total time=   1.6s
# [CV] END ...................C=100, epsilon=0.01, gamma=scale; total time=   1.6s
# [CV] END ...................C=100, epsilon=0.01, gamma=scale; total time=   1.6s
# [CV] END ...................C=100, epsilon=0.01, gamma=0.001; total time=   0.6s
# [CV] END ....................C=100, epsilon=0.1, gamma=scale; total time=   1.3s
# [CV] END ....................C=100, epsilon=0.1, gamma=scale; total time=   1.2s
# [CV] END ....................C=100, epsilon=0.1, gamma=scale; total time=   1.2s
# [CV] END ....................C=100, epsilon=0.1, gamma=scale; total time=   1.2s
# [CV] END .....................C=100, epsilon=0.1, gamma=0.01; total time=   0.6s
# [CV] END .....................C=100, epsilon=0.1, gamma=0.01; total time=   0.6s
# [CV] END ......................C=100, epsilon=0.1, gamma=0.1; total time=   1.4s
# [CV] END ......................C=100, epsilon=0.1, gamma=0.1; total time=   1.2s
# [CV] END ......................C=100, epsilon=0.1, gamma=0.5; total time=   2.8s
# [CV] END ........................C=100, epsilon=0.1, gamma=1; total time=   4.9s
# [CV] END ....................C=100, epsilon=0.5, gamma=scale; total time=   0.2s
# [CV] END ....................C=100, epsilon=0.5, gamma=scale; total time=   0.2s
# [CV] END ....................C=100, epsilon=0.5, gamma=0.001; total time=   0.2s
# [CV] END ....................C=1, epsilon=0.001, gamma=scale; total time=   0.5s
# [CV] END ....................C=1, epsilon=0.001, gamma=0.001; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.001, gamma=0.1; total time=   0.5s
# [CV] END ........................C=1, epsilon=0.001, gamma=1; total time=   0.6s
# [CV] END .....................C=1, epsilon=0.01, gamma=scale; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.01, gamma=0.01; total time=   0.5s
# [CV] END .......................C=1, epsilon=0.01, gamma=0.5; total time=   0.5s
# [CV] END .........................C=1, epsilon=0.01, gamma=1; total time=   0.5s
# [CV] END ......................C=1, epsilon=0.1, gamma=0.001; total time=   0
total time=   0.0s
# [CV] END .................C=1000, epsilon=0.001, gamma=scale; total time=  11.7s
# [CV] END .................C=1000, epsilon=0.001, gamma=scale; total time=  13.5s
# [CV] END ..................C=1000, epsilon=0.01, gamma=0.001; total time=   1.0s
# [CV] END ..................C=1000, epsilon=0.01, gamma=0.001; total time=   1.0s
# [CV] END ..................C=1000, epsilon=0.01, gamma=0.001; total time=   1.0s
# [CV] END ..................C=1000, epsilon=0.01, gamma=0.001; total time=   1.0s
# [CV] END ...................C=1000, epsilon=0.01, gamma=0.01; total time=   2.4s
# [CV] END ...................C=1000, epsilon=0.01, gamma=0.01; total time=   2.1s
# [CV] END ...................C=1000, epsilon=0.01, gamma=0.01; total time=   1.9s
# [CV] END ...................C=1000, epsilon=0.01, gamma=0.01; total time=   2.1s
# [CV] END ....................C=1000, epsilon=0.01, gamma=0.1; total time=   9.7s
# [CV] END ....................C=1000, epsilon=0.01, gamma=0.1; total time=   9.7s
# [CV] END ....................C=1000, epsilon=0.01, gamma=0.5; total time=  42.6s
# [CV] END ....................C=1000, epsilon=0.01, gamma=0.5; total time=  44.9s
# [CV] END .....................C=1000, epsilon=0.1, gamma=0.5; total time=  29.8s
# [CV] END .......................C=1000, epsilon=0.1, gamma=1; total time=  46.1s
# [CV] END ...................C=1000, epsilon=0.5, gamma=scale; total time=   0.5s
# [CV] END ...................C=1000, epsilon=0.5, gamma=scale; total time=   0.5s
# [CV] END ...................C=1000, epsilon=0.5, gamma=scale; total time=   0.5s
# [CV] END ...................C=1000, epsilon=0.5, gamma=scale; total time=   0.6s
# [CV] END ...................C=1000, epsilon=0.5, gamma=0.001; total time=   0.3s
# [CV] END ...................C=1000, epsilon=0.5, gamma=0.001; total time=   0.3s
# [CV] END ...................C=1000, epsilon=0.5, gamma=0.001; total time=   0.3s
# [CV] END ....................C=1000, epsilon=0.5, gamma=0.01; total time=   0.5s
# [CV] END ....................C=1000, epsilon=0.5, gamma=0.01; total time=   0.5s
# [CV] END ....................C=1000, epsilon=0.5, gamma=0.01; total time=   0.4s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.1; total time=   0.5s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.1; total time=   0.6s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.5; total time=   0.2s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=1000, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .......................C=1000, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .......................C=1000, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END ......................C=1000, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END ......................C=1000, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END ......................C=1000, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END .......................C=1000, epsilon=1, gamma=0.1; total time=   0.1s
# [CV] END .......................C=1000, epsilon=1, gamma=0.1; total time=   0.1s
# [CV] END .......................C=1000, epsilon=1, gamma=0.5; total time=   0.0s
# [CV] END .......................C=1000, epsilon=1, gamma=0.5; total time=   0.0s
# [CV] END .......................C=1000, epsilon=1, gamma=0.5; total time=   0.0s
# [CV] END .........................C=1000, epsilon=1, gamma=1; total time=   0.0s
# [CV] END .........................C=1000, epsilon=1, gamma=1; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=scale; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END .....................C=1000, epsilon=2, gamma=0.001; total time=   0.0s
# [CV] END ......................C=1000, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END ......................C=1000, epsilon=2, gamma=0.01; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.1; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .......................C=1000, epsilon=2, gamma=0.5; total time=   0.0s
# [CV] END .........................C=1000, epsilon=2, gamma=1; total time=   0.0s
# Best Parameters: {'C': 10, 'epsilon': 0.1, 'gamma': 0.5}
# Optimized SVM Mean Squared Error: 0.07866405434981413
# Optimized SVM R-squared: 0.9247052629183881

# %%
# Scatter plot: Actual vs Predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test["log10(mass)"], predictions, alpha=0.5, label="Predictions")
plt.plot([min(y_test["log10(mass)"]), max(y_test["log10(mass)"])], 
         [min(y_test["log10(mass)"]), max(y_test["log10(mass)"])], 
         'r--', label="Perfect Fit")

plt.xlabel("Actual log10(mass)")
plt.ylabel("Predicted log10(mass)")
plt.title("Parity Plot: SVM Predictions vs. Actual Values")
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
residuals = y_test["log10(mass)"] - predictions
plt.scatter(y_test["log10(mass)"], residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')

plt.xlabel("Actual log10(mass)")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual Plot: SVM Model")
plt.show()

# %% [markdown]
# Multi-Layer Perceptron (MLP)

# %%
# Step 1: Filter the dataset for bright objects (F444W ≤ 25)
df_filtered = df_merged.loc[df_merged['F444W'] <= 25]

# Step 2: Define input features, target variable, and error columns
input_features = ["F090W", "F150W", "F200W", "F277W", "F356W", "F410M", "F444W", "z_m1(EAZY)"]
error_columns = ["eF090W", "eF115W", "eF150W", "eF200W", "eF277W", "eF356W", "eF410M", "eF444W"]
target_variable = "log10(mass)"

# Step 3: Prepare input/output datasets
X = df_filtered[input_features]
X_errors = df_filtered[error_columns]  # Magnitude errors as weights
y = df_filtered[[target_variable]]

# Step 4: Train/test split
X_train, X_test, X_err_train, X_err_test, y_train, y_test = train_test_split(
    X, X_errors, y, test_size=0.3, random_state=42)

# Step 5: Standardize inputs and output
scaler_X = StandardScaler()
scaler_y = StandardScaler()
scaler_X_err = StandardScaler()  # Normalize error weights too

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

X_err_train_scaled = scaler_X_err.fit_transform(X_err_train)
X_err_test_scaled = scaler_X_err.transform(X_err_test)

# Step 6: Compute Sample Weights
# Average magnitude errors for each sample (so we have one weight per row)
sample_weights = np.clip(1 / (np.mean(X_err_train_scaled, axis=1) + 1e-6), 0.1, 10)

# Step 7: Define MLP Model
input_layer = keras.Input(shape=(X_train_scaled.shape[1],))

hidden1 = layers.Dense(128, activation='relu')(input_layer)
hidden2 = layers.Dense(64, activation='relu')(hidden1)
hidden3 = layers.Dense(32, activation='relu')(hidden2)

output_layer = layers.Dense(1)(hidden3)  # Single output for `log10(mass)`

model = keras.Model(inputs=input_layer, outputs=output_layer)

# Step 8: Compile the Model (No custom loss needed anymore)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4), loss='mse', metrics=['mae'])

# Step 9: Train the Model using Sample Weights
history = model.fit(X_train_scaled, y_train_scaled, 
                    validation_data=(X_test_scaled, y_test_scaled), 
                    sample_weight=sample_weights,  # <--- Pass the weights here
                    epochs=100, batch_size=32, verbose=1)

# Step 10: Make Predictions
y_pred_scaled = model.predict(X_test_scaled)

# Convert predictions back to original scale
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_scaled)

# Remove NaN values before evaluation
mask = ~np.isnan(y_pred).flatten() & ~np.isnan(y_test_original).flatten()
y_pred_clean = y_pred[mask]
y_test_clean = y_test_original[mask]

# Compute metrics only on valid data
mse_nn = mean_squared_error(y_test_clean, y_pred_clean)
r2_nn = r2_score(y_test_clean, y_pred_clean)

print(f'Neural Network Mean Squared Error: {mse_nn}')
print(f'Neural Network R-squared: {r2_nn}')
# Out:
# Epoch 1/100
# W0000 00:00:1738454218.283553   23679 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7589 - mae: 0.7523 - val_loss: 0.8615 - val_mae: 0.7181
# Epoch 2/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Neural Network Mean Squared Error: 0.12280564838003213
# Neural Network R-squared: 0.8824543295748237

# %%
# ---- Check Overfitting for SVM ----
# Compute Train Performance for SVM
y_train_pred_svm = best_svr.predict(X_train_scaled)
mse_train_svm = mean_squared_error(y_train, scaler_y.inverse_transform(y_train_pred_svm.reshape(-1, 1)))
r2_train_svm = r2_score(y_train, scaler_y.inverse_transform(y_train_pred_svm.reshape(-1, 1)))

# Compute Test Performance for SVM
y_test_pred_svm = best_svr.predict(X_test_scaled)
mse_test_svm = mean_squared_error(y_test_clean, y_pred_clean)
r2_test_svm = r2_score(y_test_clean, y_pred_clean)

print(f"\n🔥 **SVM Overfitting Check** 🔥")
print(f"Train MSE: {mse_train_svm:.4f}, Train R²: {r2_train_svm:.4f}")
print(f"Test MSE: {mse_test_svm:.4f}, Test R²: {r2_test_svm:.4f}")

# ---- Perform Cross-Validation for SVM ----
cv = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores_svm = cross_val_score(best_svr, X_train_scaled, y_train_scaled[:, 0], cv=cv, scoring="r2")

print(f"\n📊 **SVM Cross-Validation Scores (5-Fold)**: {cv_scores_svm}")
print(f"Mean CV R²: {cv_scores_svm.mean():.4f} ± {cv_scores_svm.std():.4f}")

# ---- Check Overfitting for Neural Network ----
# Compute Train Performance for Neural Network
y_train_pred_nn_scaled = model.predict(X_train_scaled)
y_train_pred_nn = scaler_y.inverse_transform(y_train_pred_nn_scaled)

mse_train_nn = mean_squared_error(y_train, y_train_pred_nn)
r2_train_nn = r2_score(y_train, y_train_pred_nn)

# Compute Test Performance for Neural Network
mse_test_nn = mean_squared_error(y_test_clean, y_pred_clean)
r2_test_nn = r2_score(y_test_clean, y_pred_clean)

print(f"\n🔥 **Neural Network Overfitting Check** 🔥")
print(f"Train MSE: {mse_train_nn:.4f}, Train R²: {r2_train_nn:.4f}")
print(f"Test MSE: {mse_test_nn:.4f}, Test R²: {r2_test_nn:.4f}")

# ---- Plot Learning Curve for Neural Network ----
plt.figure(figsize=(8, 6))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss", linestyle="dashed")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Neural Network Learning Curve")
plt.legend()
plt.show()
# Out:
# 🔥 **SVM Overfitting Check** 🔥
# Train MSE: 0.0625, Train R²: 0.9404
# Test MSE: 0.1228, Test R²: 0.8825
#
# 📊 **SVM Cross-Validation Scores (5-Fold)**: [0.88277716 0.89615974 0.91515987 0.90774265 0.90656993]
# Mean CV R²: 0.9017 ± 0.0112
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
#
# 🔥 **Neural Network Overfitting Check** 🔥
# Train MSE: 0.1189, Train R²: 0.8865
# Test MSE: 0.1228, Test R²: 0.8825
# [CV] END ....................C=1000, epsilon=0.5, gamma=0.01; total time=   0.4s
# [CV] END ....................C=1000, epsilon=0.5, gamma=0.01; total time=   0.5s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.1; total time=   0.6s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.1; total time=   0.5s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.1; total time=   0.7s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.5; total time=   0.2s
# [CV] END .....................C=1000, epsilon=0.5, gamma=0.5; total time=   0.1s
# [CV] END .......................C=1000, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .......................C=1000, epsilon=0.5, gamma=1; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=scale; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=scale; total time=   0.0s
# [CV] END .....................C=1000, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END .....................C=1000, epsilon=1, gamma=0.001; total time=   0.1s
# [CV] END ......................C=1000, epsilon=1, gamma=0.01; total time=   0.1s
# [CV] END ......................C=1000, epsilon=1, gamma=0.01; total time=   0.1s
# [CV]